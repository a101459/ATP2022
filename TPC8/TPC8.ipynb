# %%
#Questão2
import tpc8
# Out:
# Atores participantes nos filmes armazenados: ['Ben Stiller', 'Billy Crystal', 'Blythe Danner', 'Charlize Theron', 'Cuba Gooding, Jr.', 'Lisa Kudrow', 'Owen Wilson', 'Robert De Niro', 'Teri Polo']
# Filmes de Comédia: ['Analyze That', 'Meet the Parents']
# O filme com o maior elenco é: Meet the Parents
# Distribuição de filmes por género: {'Comedy': 2, 'Drama': 2, 'Biography': 1, 'Thriller': 1}

# %%
tpc8.inicDiferente("Está um ótimo dia!", "Hoje é um dia feliz.")
# Out:
# 4

# %%
tpc8.acimaMedia(5)

# %%
tpc8.merge([1,2,6,9], [3,4,7,12])
# Out:
# [1, 2, 3, 4, 6, 7, 9, 12]
